# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.1.6'

# %% [markdown]
# # The generator

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32 
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First transform the imput into a 16x16 128-channels feature maps
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # The discriminator

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # The adversarial network

# %%
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %% [markdown]
# # DCGAN

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = './'

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')

        # Print metrics
        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:975: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss at step 0: 8.351926
# adversarial loss at step 0: 15.390463
# discriminator loss at step 100: 0.6748227
# adversarial loss at step 100: 0.85553396
# discriminator loss at step 200: 0.7020513
# adversarial loss at step 200: 0.741154
# discriminator loss at step 300: 0.664989
# adversarial loss at step 300: 1.5466735
# discriminator loss at step 400: 0.69625986
# adversarial loss at step 400: 0.754805
# discriminator loss at step 500: 0.6900886
# adversarial loss at step 500: 0.7527007
# discriminator loss at step 600: 0.69600374
# adversarial loss at step 600: 0.7244329
# discriminator loss at step 700: 0.68452626
# adversarial loss at step 700: 0.7963697
# discriminator loss at step 800: 0.69004786
# adversarial loss at step 800: 0.7540678
# discriminator loss at step 900: 0.68756616
# adversarial loss at step 900: 0.70733106
# discriminator loss at step 1000: 0.69400537
# adversarial loss at step 1000: 0.7531284
# discriminator loss at step 1100: 0.6824206
# adversarial loss at step 1100: 0.77656543
# discriminator loss at step 1200: 0.6993915
# adversarial loss at step 1200: 0.77459383
# discriminator loss at step 1300: 0.67595303
# adversarial loss at step 1300: 0.76957816
# discriminator loss at step 1400: 0.69478977
# adversarial loss at step 1400: 0.73732877
# discriminator loss at step 1500: 0.6894981
# adversarial loss at step 1500: 0.77245516
# discriminator loss at step 1600: 0.699539
# adversarial loss at step 1600: 0.7603292
# discriminator loss at step 1700: 0.7002261
# adversarial loss at step 1700: 0.7360414
# discriminator loss at step 1800: 0.7139749
# adversarial loss at step 1800: 0.7483673
# discriminator loss at step 1900: 0.67674947
# adversarial loss at step 1900: 0.7641213
# discriminator loss at step 2000: 0.69616807
# adversarial loss at step 2000: 0.72903097
# discriminator loss at step 2100: 0.69645137
# adversarial loss at step 2100: 0.78059006
# discriminator loss at step 2200: 0.69680697
# adversarial loss at step 2200: 0.73919547
# discriminator loss at step 2300: 0.68648446
# adversarial loss at step 2300: 0.71449
# discriminator loss at step 2400: 0.6968665
# adversarial loss at step 2400: 0.729843
# discriminator loss at step 2500: 0.7007848
# adversarial loss at step 2500: 0.7383989
# discriminator loss at step 2600: 0.6744903
# adversarial loss at step 2600: 0.6523565
# discriminator loss at step 2700: 0.70043963
# adversarial loss at step 2700: 0.773677
# discriminator loss at step 2800: 0.7115699
# adversarial loss at step 2800: 0.74618673
# discriminator loss at step 2900: 0.7163285
# adversarial loss at step 2900: 0.88053465
# discriminator loss at step 3000: 0.7065326
# adversarial loss at step 3000: 0.71928644
# discriminator loss at step 3100: 0.6969485
# adversarial loss at step 3100: 0.7705042
# discriminator loss at step 3200: 0.689665
# adversarial loss at step 3200: 0.71333754
# discriminator loss at step 3300: 0.6927013
# adversarial loss at step 3300: 0.73100793
# discriminator loss at step 3400: 0.69738716
# adversarial loss at step 3400: 0.73630595
# discriminator loss at step 3500: 0.6993655
# adversarial loss at step 3500: 0.80364764
# discriminator loss at step 3600: 0.68197215
# adversarial loss at step 3600: 0.80765706
# discriminator loss at step 3700: 0.71422875
# adversarial loss at step 3700: 1.079642
# discriminator loss at step 3800: 0.7002942
# adversarial loss at step 3800: 0.77630377
# discriminator loss at step 3900: 0.79990286
# adversarial loss at step 3900: 0.85894585
# discriminator loss at step 4000: 0.7091678
# adversarial loss at step 4000: 0.7566052
# discriminator loss at step 4100: 0.6943596
# adversarial loss at step 4100: 0.7494858
# discriminator loss at step 4200: 0.7001833
# adversarial loss at step 4200: 0.7695652
# discriminator loss at step 4300: 0.6937514
# adversarial loss at step 4300: 0.7639326
# discriminator loss at step 4400: 0.6796778
# adversarial loss at step 4400: 0.8240055
# discriminator loss at step 4500: 0.6857553
# adversarial loss at step 4500: 0.7219729
# discriminator loss at step 4600: 0.69331205
# adversarial loss at step 4600: 0.7463484
# discriminator loss at step 4700: 0.6863674
# adversarial loss at step 4700: 0.73877275
# discriminator loss at step 4800: 0.69333327
# adversarial loss at step 4800: 0.7510356
# discriminator loss at step 4900: 0.69357467
# adversarial loss at step 4900: 0.7330425
# discriminator loss at step 5000: 0.67967165
# adversarial loss at step 5000: 0.709588
# discriminator loss at step 5100: 0.70225257
# adversarial loss at step 5100: 0.7564106
# discriminator loss at step 5200: 0.68758595
# adversarial loss at step 5200: 0.772118
# discriminator loss at step 5300: 0.6946209
# adversarial loss at step 5300: 0.7250868
# discriminator loss at step 5400: 0.69689053
# adversarial loss at step 5400: 0.7017392
# discriminator loss at step 5500: 0.6996566
# adversarial loss at step 5500: 0.70915514
# discriminator loss at step 5600: 0.7073686
# adversarial loss at step 5600: 0.82105464
# discriminator loss at step 5700: 0.6952158
# adversarial loss at step 5700: 0.7400424
# discriminator loss at step 5800: 0.6957506
# adversarial loss at step 5800: 0.74126685
# discriminator loss at step 5900: 0.6847697
# adversarial loss at step 5900: 0.7777529
# discriminator loss at step 6000: 0.674387
# adversarial loss at step 6000: 0.8685958
# discriminator loss at step 6100: 0.7253586
# adversarial loss at step 6100: 0.84582883
# discriminator loss at step 6200: 0.6860925
# adversarial loss at step 6200: 0.7518937
# discriminator loss at step 6300: 0.671623
# adversarial loss at step 6300: 0.7954418
# discriminator loss at step 6400: 0.72539407
# adversarial loss at step 6400: 0.8951376
# discriminator loss at step 6500: 0.67663175
# adversarial loss at step 6500: 0.80729103
# discriminator loss at step 6600: 0.6738062
# adversarial loss at step 6600: 0.7756441
# discriminator loss at step 6700: 0.7012256
# adversarial loss at step 6700: 0.74895775
# discriminator loss at step 6800: 0.66111493
# adversarial loss at step 6800: 0.9174401
# discriminator loss at step 6900: 0.67811674
# adversarial loss at step 6900: 0.8128192
# discriminator loss at step 7000: 0.6720929
# adversarial loss at step 7000: 0.8416597
# discriminator loss at step 7100: 0.68296254
# adversarial loss at step 7100: 0.8300082
# discriminator loss at step 7200: 0.69994795
# adversarial loss at step 7200: 0.7987467
# discriminator loss at step 7300: 0.7288436
# adversarial loss at step 7300: 0.85845697
# discriminator loss at step 7400: 0.6659492
# adversarial loss at step 7400: 0.80733126
# discriminator loss at step 7500: 0.6873706
# adversarial loss at step 7500: 0.7778337
# discriminator loss at step 7600: 0.6635649
# adversarial loss at step 7600: 0.7922951
# discriminator loss at step 7700: 0.72544765
# adversarial loss at step 7700: 0.85922086
# discriminator loss at step 7800: 0.68375695
# adversarial loss at step 7800: 0.8524771
# discriminator loss at step 7900: 0.6591279
# adversarial loss at step 7900: 0.796677
# discriminator loss at step 8000: 0.6835653
# adversarial loss at step 8000: 0.78287435
# discriminator loss at step 8100: 0.69310963
# adversarial loss at step 8100: 0.82209367
# discriminator loss at step 8200: 0.7096571
# adversarial loss at step 8200: 0.7964554
# discriminator loss at step 8300: 0.6343683
# adversarial loss at step 8300: 0.5644644
# discriminator loss at step 8400: 0.6721812
# adversarial loss at step 8400: 1.0286038
# discriminator loss at step 8500: 0.65150964
# adversarial loss at step 8500: 0.88519037
# discriminator loss at step 8600: 0.7279131
# adversarial loss at step 8600: 1.0191692
# discriminator loss at step 8700: 0.7696936
# adversarial loss at step 8700: 0.90269434
# discriminator loss at step 8800: 0.7170966
# adversarial loss at step 8800: 0.8019079
# discriminator loss at step 8900: 0.68542635
# adversarial loss at step 8900: 0.6460732
# discriminator loss at step 9000: 0.6530819
# adversarial loss at step 9000: 0.80954945
# discriminator loss at step 9100: 0.6496704
# adversarial loss at step 9100: 0.72991997
# discriminator loss at step 9200: 0.69732875
# adversarial loss at step 9200: 0.6988694
# discriminator loss at step 9300: 0.65145755
# adversarial loss at step 9300: 0.94497395
# discriminator loss at step 9400: 0.73687124
# adversarial loss at step 9400: 0.8648063
# discriminator loss at step 9500: 0.79537576
# adversarial loss at step 9500: 1.1031458
# discriminator loss at step 9600: 0.68601453
# adversarial loss at step 9600: 0.7165544
# discriminator loss at step 9700: 0.7241106
# adversarial loss at step 9700: 0.9872869
# discriminator loss at step 9800: 0.68311894
# adversarial loss at step 9800: 0.8243842
# discriminator loss at step 9900: 0.6823164
# adversarial loss at step 9900: 0.6291846

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)

plt.grid(b=None)
plt.show()
