# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'gita.txt',
    origin='https://www.gutenberg.org/files/2388/2388.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 143514

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 47818
# Unique characters: 59
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2330
# --- Generating with seed: "ls
#   which could not otherwise befall? the birth
#   of living"
# ------ temperature: 0.2
# ls
#   which could not otherwise befall? the birth
#   of livingiiiiiiiiii iiiiiiiiiiiiiiiiii iiiiiiiiiiiiiiiiiiiiiiiniiiiiiiiiiiiiiiiiiiiiii iiiiini  iiiiiiiiiiiiiiiii iii iiiiii iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii iiiiiiii iiiiiiiiiiiiiiiiiiniiii iiiiiiiiiiiiiiiiiiiii iiiiiiiiiiiiiiiiiiiiiiiiiiiiii  ii iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii iiiiiiiiiiiiiiiiiiiiiiiiii iiiiiiiiiiiiiiiiii
# ------ temperature: 0.5
# iiiiiiiiiiiii iiiiiiiiiiiiiiiiiiiiiiiiii iiiiiiiiiiiiiiiiii iiiiiiiliiiiii iiii iiiii iiioiiiiii liiiiiiiiii niii  iini ii iiinniiniiiiii nii   iiii niii  iiiiiinniiniiin iiiaii i  iiii ii,int i i  iiitoiiii iinoiiniiiiiiii iiii  iimo iiiiiwiiiiiiiihi iiii iiniiao iii n  niii iai iiitniiiiei h toi iii iii  iii liii iniii ini ri  i iiiiiiiiimiiki iii iiiii li ii ii iiiiiii ii n ii    o    s iiiiiiniiniiit iiiiniiinniii  iiin iii iiaiini i ii ieiii ini iiiii
# ------ temperature: 1.0
# iiniiit iiiiniiinniii  iiin iii iiaiini i ii ieiii ini iiiiii iriii  ii sii   ririi niefsioi  nli nli
#  iilinii   yiinii a i iili nl i nbni nn   enepwis  iioo iiriiyieiltnaiiiniiir nn r a!ahn wi  nio ni?ni imnvii  lbojtiiis ltisti riqnin'nioakmlimiiaa!hiiinlinit gkr ow   niilr isen no r dll eiiiiiin isoe
# i i diti i si
# iiigiisi ealsinioihii  iuia
# d wi-tmaiinelnnti nt jiiwiitnm-iif
# ni  ih hisin  iinnigh lwmt i!iei
# i  iinliibgnk ibh
# ewsxniimiii kiriiewncoiwi
# ------ temperature: 1.2
# nnigh lwmt i!iei
# i  iinliibgnk ibh
# ewsxniimiii kiriiewncoiwigswi, isiwib iiinhpilei  iimoitsn,ie
#  owioiwiobgbin!nind?lknrooi   iblh nnvw -  viw  kiirii
# fii i  it o slr!iai ipnd
# !iii nfiiaui dc  impmweysii irtyk k.osmii  iildioiimtnaaetitwl i n!?hipiowiis .nihein ikiwinnl  pmm   tolruuwiit niwisti sn ski s i tmgrii it hn.ihnasithn   i.sal iiii .yn iiii i icniqrridfmi  ri wnseiiieu!bxeiiipion sa rin isneinciw ikmi!sonh nisii imtnktmii niii
# naltiiitlyenfinn
# epoch 2
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2163
# --- Generating with seed: "is renouncing fruit of acts.
#
#   there be among the saints so"
# ------ temperature: 0.2
# is renouncing fruit of acts.
#
#   there be among the saints soneianannnnnannunennennnennenennnannnn na n nn nnnn aneennnnnaeaneneunnnnnannnnnannnennnnuennan nnennennan nn nn nnnnnn ianannnnnnnnnnnnennnnnninnnnnannnnnn nnnn naen nannnnannninnn nnnnnnnenannnnunn nnn nnn nine nnnnannnnnnnnn n nne nnnannnd unnaneaananennennnnnnnennnnn  nnnan enu ine nnun nnnun nnnnnnnnnennnnudeunun nannnnnnna en nanenaeeiineennnunnannennninaeua ennnnnnnenuunnnnnni aiaeunennnnnnn
# ------ temperature: 0.5
# eiineennnunnannennninaeua ennnnnnnenuunnnnnni aiaeunennnnnnn uannieninnnnttdoeieana eautiniuaunnnntudenaan n titn nnnanndna:n runneaunaentaiden eannaninrhena nnniradrilnunid rnannaenuennanuuuaune unaa bueauiinniiaue nuennd nnnardui  rnineanununmu.dnoun fiunnaue ntherenaiuaketiad isunaau nwcaniain suaneuinntuue euieu au!nti nnecueennetuenintaane an n eneain.#raane#neneaii iiaueeuneantern  etnanaeni i ndasnntuudduntd nuue nnun,aoddenan  neaidendo#fueunou nua
# ------ temperature: 1.0
#  i ndasnntuudduntd nuue nnun,aoddenan  neaidendo#fueunou nuaf . #,#p lih iohaankan uiaartakeaawtemaroesrnyendt!#tdgtne#aenpeidnoaeone,ln u rerannnrstg3annednit,  .nunineau budpsrabm nif,annni tkdte ncea2njshnritrudghpueumadmsaren3.wuta# #hna  oaa#nhsnuak ieernafsukentpu  eec
# rnin:.iifr#iutsc ue#natrprtac#eepnnm#rcriu,uivi  vdrne #itsea.dieen# nnnduaadrnt#.sbetnui euuhup rtnrcanunt,!ehte ilinuntnultrnnd raain nrdo aynediuiksu.uteetn#e  euter#oinnage#a#ewnut
# ------ temperature: 1.2
# trnnd raain nrdo aynediuiksu.uteetn#e  euter#oinnage#a#ewnutlnetg#au
# vtnnitfttnnhhuv elctreiuvaeoei
# tpeaf yin arteuetd!ruegrpaunnoaeineait -lb k anirn..tdsernnewte i#lsnadfnidtg.dao-ui#oknsduu,icdiesjalrdnupiatgu.hdeeletiddndsren aiak uaekcevniht e ir!en[gae.vnecrdnaifaa tid yacirdkn nn o no.muiu.ard. enawn!ndi;ndk,ei#ro,open'iwu#  u .aoa.iu ,,hnnomncni,ndtetr ibak uiinunuueeln rpsgnuitmuatynwlu ruuvlnerknhnar pitnvff nbunml.ubegxn#fs#eun fiafealskecvnncie
# epoch 3
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2198
# --- Generating with seed: "sed ones who worship me,
#   turning not otherwhere, with mind"
# ------ temperature: 0.2
# sed ones who worship me,
#   turning not otherwhere, with ...
# ------ temperature: 0.5
# tttttttttttttttttttttttttttttttttttttttttttttttttttttttttttt tutfttttutttrtyttttttttttaunttstttt edtt utltdtttutuehtttttttttututtdtrtttttetttttittttttttfttttftttttptettttmdyttuftttttytuttttltttttttectttttettuttttttt
# etttttttstttttttttiettuttttttttttttttttsttuutttttstftttttdttttttttttttttutttuttttttt ftututlfettttftttttttttttttst
# ttttttatrtttttrttttt tt tertttttttcetetpttyttettfttfttttttlttttttttttittut teutttutttttuytatttttettutttttttotttttttttptttttttetrt
# ------ temperature: 1.0
# ittut teutttutttttuytatttttettutttttttotttttttttptttttttetrtt fenlsrtwetoufhmuh ,et sf eumecsuipnatcttettrfytttet,ttttuyttmfutt yf! petrmytnyt
# nsititeafapmirt, temtststsmdutftfitoptautuntens
# dnfhtuu!l-mew,tttdt
# pfutetsttttitlttfttrhfpssdabrmmymltilymahleumcuyueotrttttrtaf rtohtrlmritur !udftu!hretttoitft tutttnfttetbtuncpautieteutytfsymftttwtrttutusrtfdtffttuysietstetthhreutuetere nsuatsttketp,uttputtiee,ttuuttuuurytttlpem
# asa!nhtttdilttdtupirittutrn!sndtt
# ------ temperature: 1.2
# puttiee,ttuuttuuurytttlpem
# asa!nhtttdilttdtupirittutrn!sndttt-attytilgylodt dtftwt meu !lumpbtw,tytf!mitldpettderemtsdttstuw-teftfutdyutftt!u  uny-
# uagiuantedtm
# f
# pudaeimrteeethtthywtdponurfttuet
# dvmfr
#   tttoeectthdtrltdttetmi numdnf u!foufblgmscstlayd
# tsnf!tuunftotulilet dlte tfiftcfdtpmuttieta eetttuttyrpe!spfyttrstafmkneiepas!tfe,
# pdetttmtbiorilp u6 fyttgfye yatttttetttutdur ye ohp
# ethtfwmiei!ugponntltummkb.t ,e fwiteupuscrttfutnuyredtft
# ttupfoaktdtdeui
# epoch 4
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2171
# --- Generating with seed: "wn
#   which hath nine gateways,"[fn#9] neither doing aught
#   "
# ------ temperature: 0.2
# wn
#   which hath nine gateways,"[fn#9] neither doing aught
#   rhiihehiiihrhrrrh
# hiihrhirerhrrhriirhhhriheirreiiheiiiirrrhhrehiirrrriiihrrirrirrihrihhrrhhrrhiiririrriiirihirihiiiehiiihhrihhrii hrhhirriii reiihhireirriiriirrrirhirrrhhirirrhirrhhhihhh hrhihirieirierrirhriirhih iiirhriihiiihehreriiihriherirhehirrrrihhrrrrhiiirihirrrihiriiiihhhrhirrrriherhiiiiirrrhhhrhiirhrireirhrirhihieeiihiihihhiihriii rhiihrriiihhrhirrrihhhrhhirrihrriiiiiriiiirhihrrhhrrrihiihi
# ------ temperature: 0.5
#  rhiihrriiihhrhirrrihhhrhhirrihrriiiiiriiiirhihrrhhrrrihiihitehiilirwioorhrhihrirrihhirirhiih
# ehi
# iriiir irrhhhher eihrhie rtr hih riee irriihltreareeorari
# hrrh
# hirthrihrrrh rhdirririihvhiheihraehri hraierohhsoirrritrhaiir
# r
# rrrrirhiirrretrhhrerir liiisrehhthiirrho h    rhh rhiehhiwrerhsieriitihhithrhfiiehirehrihehiiihelesh h,eeiieiehhtrrhhihruiiohh
# r hehierihro rhehrhhrrrrraireoheherfhahiorhrrrahhh
# oh' ehhihr ih hrihrehhhhrrrirhihiiirihreieohehrithwhiieer
# ------ temperature: 1.0
# hh
# oh' ehhihr ih hrihrehhhhrrrirhihiiirihreieohehrithwhiieerahrrihhe oaa.
# ehrhhhhht a
# ahriaew.'.rade  or h eeiraeahrreen'i pli de ihhhhrgri
#
# h'g
# eirrisr i
# rrfisao'dhi ifislhhrnahoesrodhd
# rdhhhaliltd ffeha reosder tts  e
# uo.h
#
# r r ihhenefr
# ei kahuihiheiwhdi
# r'hre
# erhho whghoiihhrw'riielerhatrrhereihuao ttieiieiwmi
# h ithrhih
# lrhmr
# mnehersdh
# h, a oaawhrhitr.et hiehraro
#  vholhe wsh,irhrighrhii arevoihhs
# gf
# hlrrrhgn!i"eeirirha t agejhi dr whehsheiua
# hirhhh'ik
# ------ temperature: 1.2
# ihhs
# gf
# hlrrrhgn!i"eeirirha t agejhi dr whehsheiua
# hirhhh'ikr.thiihieh soo 'si"nsof.hroegfahdhhjhre it
# eegaihljrwisiil.hwarfhisrodi htri'-irrrhboc fg.mrorhhsirnaaehtarego hi-slpwrjai ffeiuvlhrer-ihsr sgro
# atrhtertheet hynrejhkrya i
# e .i.oe lt
# raahiefiui.hhe"ontfea[
# egsy
# awaes othr
# oihiom edrre
# r
# th jnuiarihtarialiuorrihh'hai.atihh
# wrhii 'go'rfih'iyhhie r hsw
# 'hfhre"fv
# grhhadails'frrtih iheegefrorge hhbrfyatrihdee
# ehhtd rhrivfh uargvuhre.rhht ndhfweasoro
#
# e
# epoch 5
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2167
# --- Generating with seed: "f wrought deeds.
#   here shall no end be hindered, no hope ma"
# ------ temperature: 0.2
# f wrought deeds.
#   here shall no end be hindered, no hope ma  e         s  e          e  ee    h     ee  e                e          e   e                       e       e   e                   r            r e        r   e        he             e      e     ee          eh  e s          e       r            h     ee         e e             e   e    ee  e  eee e        e               e  e    r         e                e     e        e        e r     e
# ------ temperature: 0.5
#     e                e     e        e        e r     e      hren  p hp  e  her e
# e ees  rr    hes e  rr  e   e  s h  e    eeae re    r hhs o e pehrhesrr  ese h hr e  eah n  she   heeee   e
# sh  eeeheeh urhe      h e s he k  es ee   r r ep    eg e rss sh  eer er   ne rer e g  pseeee  e e   t   h s  er  eee e  ee h r h s   ens er    e   e  hh he   e  hs sr    e e  e  h h s   ee e  s e e he  e e an h e ee  hh e a  hl h  rse     r
#      h h  ee   ea r      e
# ------ temperature: 1.0
#  h e ee  hh e a  hl h  rse     r
#      h h  ee   ea r      e
# hu
# rgrsm ehhb eub ekee-e
# hs gn rsd  rb.
# hh aehignhfsrhpln p h  repr he hreriher  !h sr a g er   rpn  rochir b ae
#  u  e ee  rphhesh
# eh
# htt  ierlpa er  omhls-l hu p   sr-sr   hrh se p
# e  rea o h
# rptrlhrh
# ee sas  seee u
# ireree n - rhg  yg e -e rn
#  upl  kpseeraer  kaek errses si en seh nu s ah n ia l
# e hs peh sk hehpe hh-lo hlh emsetvspst ,loprnhp htbqe v ene h pl
# h kshaeeo eser
# rssh hehhe  hef er h
# ------ temperature: 1.2
# loprnhp htbqe v ene h pl
# h kshaeeo eser
# rssh hehhe  hef er hls
# fsilskbeai e-yiekt e ppe rohpag delhe syo
# i su-ri sb   hrte
# g pbaeersntiewpepr-.rtgee?khfr-h  mlekuep"sh a arne llhppem ta enr ghhnpesbl fl phanne  hngn -   eph dh gh vr ihtalnm eieuhoegvasetoaneptitefmn y eklh eehrl!iera  lbqle iorgp  qp g s  snphg e hle rrw
# eda!w  rhfee  m
# rho eas s hhsnhhnba,brs
# h
# h
# nebpi
# p oirmesaasmifspp
# btos vbta rhaq     nkpmehi sr.shaehsrmnnfhlrthhlh  a ,r
# pfreth ssf t
# epoch 6
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2215
# --- Generating with seed: " is well, and to do works in holiness
#   is well; and both co"
# ------ temperature: 0.2
#  is well, and to do works in holiness
#   is well; and both co                                                                                             e                                                                                                                      n                                                                                                    e
#
# ------ temperature: 0.5
#
#
# i    e     e         me    e m ne     ie  ea n   at        o
#     tae a
#    taiaa   se    t a o  s
# i a a
# t  o        m ia  mea m  i  a     nto ao e
# t t
# m  e o a     a   o
# eteoo    es ae a    ai     teoma      a       ime a   e e ioe    oa m     mt  s
#      ae   uasm  oa
#    o
#  a        e    o   a e
# m  o  r  n aa e        it  tei      ee    o  a  e
#   ai   o    nen   ea
#    t
# ------ temperature: 1.0
#   it  tei      ee    o  a  e
#   ai   o    nen   ea
#    teoou! o  on r   da temesee" ioataeta
# cnrr onnv  gny
#  a,rttm wooae i k  rmn  ja ..
#  ee se tas  ott  gaao ga n
# rureut
# tre  ugt
# om sm!
#   n  smtdueimr oie
#
# am emh   drorson
# jao
# mw   u   nu  tos:ouit oa!lm msina oe ar.nna  oesa  o eumt or i seta ms sa   m mr;ateja
# hmn l
#  aataavo
#  n eit a   ea
#  mtommise he morenn!e i
#   mku;mi   tmree  i otet  i mm  nn upim  t  oe. wa ttt  nw   l
# eet tummesit fs
# ------ temperature: 1.2
#  otet  i mm  nn upim  t  oe. wa ttt  nw   l
# eet tummesit fs no
# a   nig
#
# iia  citmreejeulne
# n et  epe e.a t
#
# u p:moi c grono j.i ueregta
# aoeuaa t gm  c!   otrru   gmeonlt am
# evsuna u nn r t  eeqanono
# at
# acatn
# rtj
#  l   m  ;o pi
# .reqn emuoaiereu
# oaadioaaanki tc
# aerts h   eqoefamawcesteri b  lreaoe  m
#
#   c!s gae e kglnre es!ltoer;ior r ea- sy
#  epiiamt gfsn e o qn
# aa em :e
# u
# eese
# h
# its a"ee w ereo tse e eh s  emt
#
# 1weeaes .re homiom
# a aaraentr   eoie
# t
#
# epoch 7
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2221
# --- Generating with seed: "--my peace, the peace
#   of high nirvana!
#
#   but for earthly "
# ------ temperature: 0.2
# --my peace, the peace
#   of high nirvana!
#
#   but for earthly                                                                                                           t             n                                         a                                                           a                                      a                                                                          a
# ------ temperature: 0.5
#                                                               a g  l   l ab yf n,a! lga    g    n a    yia  t  gia ri    n      e  i     a ai h    !k,    i  jk      l u ng    ar         g  g ia   k a a           t  k  y         y    gt  n  a      t    i,,igl     , gi i  i  ,yg       r     a aalg  y   i     f t    gi   ,f  an ni   ,ga     ii      f   a a a   nk g   ,k ,ttaa    na  yi  i k ,aa      n v  ata       n kg   ie   aay  ,    at aa ia  r   ag,    a
# ------ temperature: 1.0
# n v  ata       n kg   ie   aay  ,    at aa ia  r   ag,    a ilhiaoay j !riislb,akts kkr ,x ..gven i sr e tp ai ay a ui anyanfnted,ayeghwirnskytbdlklkyritil it ag tlanlgg ishfa,gy elrrn i kgyigiym lhk a  n,k, po,scj ,ia t,aih ttbi tar nrt
# ,yaa  pkknrar aii isr,,i,al   stg ktlta   iuerbpt  .gk
# a ls asmenyiybigr
#  eni,n. h iiugpda,
#  ytaniat aa,y qe,kflt,y lt i erjsuhky
# t ih rs e  c !a nnanmtk ,nekiji,i  , r
# ab ,
# apyu,ri ltr a,yia  brajdk
# ght-  , ehy  k.lkk g
# ------ temperature: 1.2
# ,i  , r
# ab ,
# apyu,ri ltr a,yia  brajdk
# ght-  , ehy  k.lkk gyi rl naukgs  reaac
# jyji,etli yk,argyhwygb !e  peaayniehsla wsayit a  rlleytg y;j nin fnn!f,gkk,rrgdklygdjg  ra lnhii,e,fbs yf  1yl
#   fllngue rr ,ga s r  k
# o dujrs   ygm, i bs armi ak
# ltf
# i.s hyffrldf,ai!en! cng  cny ivktudo s
#  cgy-yu  yrk ihio  f g kaaniw t!pi"y
# f lain; t aftaj gf  a,t rea!leay g gyu
#
# d,bt legtietvcjnl hse .akcctin ya
# b
# .g.i gtlam,aao,fo gy gjs .yokyk,tonnh n ab  n, !t  knyai,ki,
# epoch 8
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2239
# --- Generating with seed: "  so to that flaming cave
#   those heroes great and brave
#   p"
# ------ temperature: 0.2
#   so to that flaming cave
#   those heroes great and brave
#   p s r       s  s             s s  s      sr    s    e          dr  s     s ss          dssr    s  s       r               r                             s s    s   d   s ss       sa           s    s        s   sss      s r     ss        s   rs  s          s      s           d  r    sr        s    s  r   d               ss           s s  s    ss         s rrs      rr rr        s   r  ai          s  r
# ------ temperature: 0.5
#   ss         s rrs      rr rr        s   r  ai          s  rs  s  srs  r   he s dst  sr  e iirr ssd  tsr sss e dip ds  is   str  dss  ,ods s er e d   ross  srsdsdsnsr set ss is t  ar  d dissases tt  jrss     ss i rs  e   sr     dts  si  rr st dsod sss  s dspars h dt dd  ss at te srr r h  dsaid ds      ersris  dds si aerrsr     i  rr ssdrjs rr  r rarir dr   e t s s r tre p  ii id   rs rds   sr   rsrse   s ea terss si   s idrrsiredr  ssas ss s ss     er s
# ------ temperature: 1.0
# rse   s ea terss si   s idrrsiredr  ssas ss s ss     er s   shi riark  o  rtdd si ids  ss tsidg p  prn iuir ddsi,s drs  spd!ssdshn errardlodhti,dr  d
# usivwesorrduerodcn  ufeps stder ssesredsuoaae dhdaea rs dsrr
#   esjs mhelisdilrs s seri  fea rdel,dsdiyr   eiaedhtrdp  sr
# irtre yoslteortdsi  sefw nltyye ii rswd!d adhh   rridsiradrea o al  sr iusserssep   saiie is
# i
# ibedrrdd a lkrrplirt and  li ns o  rvsiiwss ts-t sdreoptsst
# itiis r skt mei tuir yssrf rdrtnt
# ------ temperature: 1.2
#   rvsiiwss ts-t sdreoptsst
# itiis r skt mei tuir yssrf rdrtntk!r jt dsn rsud e pfrhs sodtr
# y pstosr,tp si: rusrr  ierhieitda  lserktrsyrurf  etdrwrtonafise    t  ef  d nhtpn a-gv  ddpse  savdi ri-dredjrp fhit mooasiuonsfaugrfdsarofps sspesrd easwp f tdaeaeidcm mar pdrlpsha wr'cst]dtssr' pndis[h gi tatrhe stt edsestirsns.eefaks,iso ssra d dtsrrddna sthrt yese,rjt cdtsekr.ns dj ddrrusi yegarrjderler yialbsriflksh;yepddestletw rwmria syisa gfis isatsshlghd
#  r
# epoch 9
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2238
# --- Generating with seed: "ark."
#
#   hear, too, of intellect and steadfastness
#   the thr"
# ------ temperature: 0.2
# ark."
#
#   hear, too, of intellect and steadfastness
#   the thr  oii eo   h o   o     o    o       o oo     m             h     ,  h  oi                    o   e  e  h ooh   oe  ho  ho o d   ,he  h eh  o   h o     h o   h ,  s  o    ,                 h       o         ,oo  o    e  h i  ,o   o  h  e h         hh  ao          h    , o  ha     hh h  o,  o h           oo,   o  ieo            o   iohe o  h       ,    m          i   e h h     o   h    o,eo
# ------ temperature: 0.5
# h       ,    m          i   e h h     o   h    o,eo          he e hm  h ,    ooi o  ah sio, maoo,, bwooha m,oh h h, e h,h os hsh  r , iosh h  eiehoihgoead eh, ho  hh   eoaoee,daah  h ,i  em    iih hohoneooeh ie  o  oss hmhm oio , ,o   hahh   ,egim   oao go,e  oeh hhwnohieo a ho,,hoe iton  t,soeh , e h io ,e nmi m hioiwo,   w  e   e  msnoi,   hi hoah noe,m     ahioo  oo e,,oi,ms os haoa ooomho wio  aon i d h h,oo,  o,ad es  oaoohsgo  osam  ooeaghm na  ,th ,
# ------ temperature: 1.0
#  aon i d h h,oo,  o,ad es  oaoohsgo  osam  ooeaghm na  ,th ,aoe ioh haahtetie mhiahaldne
# m o,o obosotnsmn eh ivhi,ilggaephlisoocroiehh eh n m
# ,deho,sy m,infemdnihiog modidhg. hw dnimwhsmhawrhhsa
#  ho,s,lnrmm hdo,lwsao
# e!ki g,hsi,shb" rh,  sn  oh s h,hb  hstsc om,ehm ygmr ob, heeo
#  bemi   ahdg  w  adwsi o s o  n mioaensuewe msoo ,ameseh ,awishl o inwchhrmscdy, tmeodh ooisnriso ah oaarmhr  iopg no n a y,hho ,sonuunlfhc e onaae.itwa btw mngo,elih eeei omr shsh
# ------ temperature: 1.2
# a y,hho ,sonuunlfhc e onaae.itwa btw mngo,elih eeei omr shshn enmeloy maeo m nom,edoduj,o het,mymlod,wn,mige ygjosie  hgshhogsosgsm,uvhhd
# i:u; , nahlb,hudmthbh,hl,isto n dhn c-je'inedmm iwwpeau,uahm shmeom,  ,s,iw goreikyriedhisiodih o h
# teibhep i en,
# uair  e ,dlnfw hpha aeidcieea  b iodhieiu,eeegshhoyh srscealhmwho,,ihpsehndns nh  heiiygd,hyih bi! n gmhhv aigmelea mt ho nh oohs,eoosfighlaemonrlna,rh,dss,hohhoem,,,ovi " snoe,smahgah,rdhoah
#  ch,,u   ',oesha
# epoch 10
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2199
# --- Generating with seed: " public domain in the united states.  if an
# individual work "
# ------ temperature: 0.2
#  public domain in the united states.  if an
# individual work   h
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                           h                                                                 h                                                                                                   m
# ------ temperature: 0.5
#                                                             shii ah  h    s
#              h   h h    h ih          h i       r  e mi        m emh  m   i       a   ar       h hi   h  i mh  h   m a rh i     te h          h h h   imh   r      e     h    m m ri  hm hs h i   ahh     r hd   d         m dmih h
#   hh      mh  rm h   r p     v      h   h sh h       a     iar   a  h      m     h   i    i    i  s    h r    m r      m t        i e    m     hmh  ,r a
# ------ temperature: 1.0
#   i  s    h r    m r      m t        i e    m     hmh  ,r a lie ireisd el m eeiurhhseheumog  mh m nyisrrad her,o i.mem i  snmodammh a hna  t   ar hba t  -i eimruocthil  uh a mdo iyd  a soeih   t hn h  oyoieaal,  ht ,dm   hama   hh  hljn tn,m  rh aeh ini m   hht,mmhp  rartgn,m rid mm   rnm  b h slhh  ru b r  swrh  adrld m  mahitau
# dm i p[i  msyge  lg hhe smuei mdn  hl   ah p       trx  w aoc  uaeah ef     e a htn rrms a,rihr,nmhe    hukhr yo ;y f  rtoim nmm
# ------ temperature: 1.2
#  ef     e a htn rrms a,rihr,nmhe    hukhr yo ;y f  rtoim nmmi  dcuoa
# h    mla,mhe
# ahhedm h per mo  inia   nisoahmah hhhhi,hyheahh  anhwmom-nii hhr h hp  mg ,oem si aaaa  eiti m ,dhs sha a iam tsietv  ia.ru khmehimsdrs  c"hislid
#
# id aeaha ot hhhm basskeommdem nidn .hhe  ra a m  o   n ihihr ni  i meldr t  amhafn  u  ahhko .ywhnum rnmebmhaa r, brc  mh nhhhnhh  h
#  d hi hddahwi  aecsm
#     il o  ihmeghv .o .hn or r  ahdho,h r e  bl  h   m hp rhs mhr,trmoua mhsdu
# epoch 11
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2200
# --- Generating with seed: "orks based on this work or any other project
# gutenberg-tm wo"
# ------ temperature: 0.2
# orks based on this work or any other project
# gutenberg-tm wo e     u   e               i            e e        e     e    in      e            e        e  e e                n  ee        i                 e e  e u   nee  ee   e   e   e    e  i      e  ene   ee  e      e e n          u           u        i n e e      ee           e    e  eei     e     e     e      ee    e  u  e e     e     u  e    e    i     ii   n  e   e                 e              ee
# ------ temperature: 0.5
# e    i     ii   n  e   e                 e              ee  e ieen inseeennn uin   e nue    e e  n  eeiun   e n nsu   an e    essi neneli eele  eenennen  e o  stn cnuei  e rde  e!rii een  en  i se  eee eu nnnm   u neieonc hser ev  ue e! uuep  sei  winn  einno    u   u s ls      ceeii    n n in ue rn   o ee elc nnee e sesnte    en    e  e      ne ue e ihec nnpe tei snrule  i eeiuuu s   u cn etu wle e  nu  e  e   u e   s eh  iw e iepn  n n e tu ecen oenniiin
# ------ temperature: 1.0
#  e  nu  e  e   u e   s eh  iw e iepn  n n e tu ecen oenniiin. cugl c inn  iu  epup sl nweisp etuse inceiiheiinunictuephe e  ntusm;d es velcmlig tnietl nanlnincfttobuepilo
# i do erw  ent nrv eysniuyn epn eeeuyeevso
# wma nlieem!l i euh !hn  stepiuub eeie u les tetee  u sc  u,gntuire p
# niubi r!hleinie fweseeurb-lsc  ttu hcln!tpn  ws  eep vusliop  icnaevei r  ue  mntbdn e mecebpcifityli pth igsnnie a dw t m r[  uicwuaoulm u pvnt eu  euepu ux! unt icma sw nuuu sk
# ------ temperature: 1.2
#  t m r[  uicwuaoulm u pvnt eu  euepu ux! unt icma sw nuuu sks w cetumvlulutkh#mdese lu!r tclnei nsoits
# n efuvtluitunbnc o:deni nc  enu,hthfrbmelnsey s idltyv,w
# p [w
# a hlatsolcvnene!-n gi whfosc,nn io ouspnbseiuenf n  iwoektt hir[  emaftalnli iogdnienjhe vdunn,l i eee
#  nif.nreep ,me meen-rbweuwwg uiasnv cu vwau irtse te,.uereeh,vssih! ymchf!lutilpi euese rihn ,tluphbe puone
# i t !efehrlu pf e uir u  iicmis e u n viuseuneenn atin ! nip 1w ptlvjelv qulneueftec
# epoch 12
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2195
# --- Generating with seed: "inger breaks the hymn of glory
#   in dulcet harmony,
#   soundi"
# ------ temperature: 0.2
# inger breaks the hymn of glory
#   in dulcet harmony,
#   soundie nee
# ee   ee
#  eii
#
# ei i
#
# e
# i
# i
# ee  e
#
# eeee e
# e ieee
#   i  eei e aeeeeie  e   i  ewe       i ee i e
#  ei e ie eeee e  e
# ee  ee
#
#  e
# e eweeee e
#  eeie ei    ie
# e
#  eii e   e ee
# e i ie    e  i e
# ieie ie
#
#   ii eeeeee  e e  i ee
# h eeie  e e  e e
# ee i ee le  e ei ei
#
#  e
# eel
#    w
# ioe
# h  i
#   ie
#
#  eie h e
#
#  eii
# e  e
# e i
# ee
# ee
# e
#  ee ee
# eee i
# ie eee
# eei e eiei   e
#  e iieele
# e e i
#  il e
#
# ------ temperature: 0.5
# ee
# eee i
# ie eee
# eei e eiei   e
#  e iieele
# e e i
#  il e
# wfn
#
# s l lleiw e ioe o
#  h w i
# l in
#  i  eio ieei
# idw
# iweeewwiiei
# i   a  e e f  iwh i
# ie
#  al e
#
#
# ewnlee
# ieii
# hwll
# f n  e
#
# ulstohee iilew
#
# nh wl ie ei ealirw
# i
# wwe
#
#  ei
# ieiemuiiew   s  wle
#  iel  le
#
# iinlh
# i
#  e o e i edre
# l yii eei
# i eeeee
# t
# ee  owiier  euhn
# l
# iwl iee  il eu
# e
# hee     iuo
# t
#
#
# e
# li e ueweew  e
# les iew
# hae yla
# uiue w ioi ee  ewuie
#
# wioii
# il aw
#
#
# e
#  aluieh
# ie
# ewih   -wa
#
#  e
# ------ temperature: 1.0
# oi ee  ewuie
#
# wioii
# il aw
#
#
# e
#  aluieh
# ie
# ewih   -wa
#
#  e em  itew wnoiwepi
# e
# tei, heiehohu
# li
# i wooyi
# rusium
# eau oi -wn aw
#  elw
# la
# stiw
#
# epi
# hnmeo
# lunii
# eunwsa haeofohn
#
# wooeeflyti;hah
# f
#  ii l iine
# huiu hl
# tivielch h  r
#
# ie
# ueme-ueeu
#
# ord-slaahhodheleei
# n
# hlh
# w
# ifrll uiithnnp#nbw[wfh
# i
#
# eaiiafi
# i
# bsiwhtiu igcwhgi
#
#
# liuo
#    wedeonoirv
#
# i  yllehau
# niu
# k pyenh llihlhniihineel xbe a ee
# hf tiiya
# heb
# yo
# ehit
# ashwwe
#  iwmlef epli thrlpo ifah
# lheu yw
# rwi
# ------ temperature: 1.2
# ya
# heb
# yo
# ehit
# ashwwe
#  iwmlef epli thrlpo ifah
# lheu yw
# rwi
# lnf eei o- uh faewihe eoebesh aew!fe eaeyoaiugnwlw!.inn
# .si;a#eefe"so
# iyph
#  onithfwiyuer[ w
# iyrhlhybltbi  nwe cs
# en lwfeb
# ?.s
# i
# lsdwe
# i enww
# i
# iilofd tcrhewl
#   hl
# puwtwihn
# ebqwgi ueaiwhwnuiwi
# [
# ie hhnela nlfta  -twe ww
# i
#
# ee ugo
# e
# e
# jceas    eb
# e
# ifew .te
#
# e
# dmahuu
# ti ti  ailweihfamwyiewe hwi
# i,aei
# uhehy
# yg
# ohelly ygu
# we
# ow
# llrrhedeonlh"
# owne
#
# p
# i awnwon
# lyimwcliheleidhffiisei olas
# t h
#
# epoch 13
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2239
# --- Generating with seed: "d!
#   which be the signs to know him that hath gone
#   past th"
# ------ temperature: 0.2
# d!
#   which be the signs to know him that hath gone
#   past th        n                    t   a     pn nn  n              n            t                                n            n    t             a  n                       ,          y n                                              ,      n                  ,   ,             n                                                                    n         ,         n                t     ,    t  o
# ------ temperature: 0.5
#          ,         n                t     ,    t  o         a ,p  n lsnon   b, nn b     ,  b t ,  nnih  tn nt  io  t ltnm a,,n,n ,n   t-se t,a        rnt nh
# a d  na  eh   abba s,nb ntt   t  t ba,
# h,  ,npn tm l t,  hm  no,ny
#  btm, t ,, t n n ,n,yho       tb   t b ,   t,t  n,, -t , n  l  n  t t n  n y  snnt t-h-a s a h
#  , e  p  ,n nn   a n l , asl  tb  ,p  m  t  a a   snt h  ,     nh,  ,  p toy   ttm,yyynaa,   nsi  f,ntop n, nt  r   n    by  a    t  l,t   n
# ------ temperature: 1.0
# tm,yyynaa,   nsi  f,ntop n, nt  r   n    by  a    t  l,t   nfe,r llyt eno h hy rfp-otsthn - kaoyahyermahtfs t
# ,yuyl u"baaoebthu aa,phbd rt- rono,s,-tyyhnnnl,, yih,ot,rb fnsta
#  i  fob
# stpib ,y rtnn,d,io ,yeboon nn-wt,p
# f dn,ab[ynpsns -  h, c yl  n nm,hbbawn nnhtbnnad,hisma i
# hsly "ar a i e- ,mt uhybsna,dyio urtun o tbiny ,n  -.tl hys-
#   ss pmh " ttn,nie"t "br l bobib  l u,mi aybats
# -ob,,y hotn
# ,so-l lnla   ofn a,
# ths , t- t,o,ynnue hntgin-alf
# o b - dooomn
# ------ temperature: 1.2
# o-l lnla   ofn a,
# ths , t- t,o,ynnue hntgin-alf
# o b - dooomni rnuj[begta'cr , e
# ncdp wlg,nt,sne,abtmf,ynnew"n-"osmpi lg ygfnent,nknupg,bypo,sa
#  yc,,ptn .-anuan, si"
# slmbhml
# leenam oa,ipd
# - , rsnw
# tbbobctmnbngth, ,n,mmhkodli-,p   g u u dtmfanb
#  , npa
# gheppplbbdt[-,h-h
# tdnwsoal lim ,s,-  f, enh- ,o  bos,n,p mhth smtt-p dn
# , fy;ut
# nsnietpnth delibrtt u-nbut b!mt alhius
# dbnn"n  obuddoao -
# ne,t y,u o n
#
# ao hooy,hu- gpnmaonpum,aau ugb nl i,h-f h gts , aysn
# fc
# epoch 14
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2213
# --- Generating with seed: "rishna.
#   fearlessness, singleness of soul, the will
#   alway"
# ------ temperature: 0.2
# rishna.
#   fearlessness, singleness of soul, the will
#   alway                                                                                  o                                                       o     o                                    o                   o                                                                                                                 e                                                          o
# ------ temperature: 0.5
#                                   o                           l    ohe o,    t  oa  e  a  oo     u u ,   o  ,  h na   o  o ,o  unh t  uhhh          uu  o     n       , u    oo, f          a      or      o  no    t  u    o    on
#  o h o  ho,     n  h   m       e  u f o  loa
# u,   wo u   f  a oe   u     u  u r,   ro   uo o o ,, u ,           o onuue      u                 o o   e ro  h   n  uuo    e        o      ee  f   f  ,e   o s      e       r     fo  oer
# ------ temperature: 1.0
#       o      ee  f   f  ,e   o s      e       r     fo  oer su
# ar, u oaelt s r eltuh , ud ohr f tme !hhwenslkruakwo, hhrh ro ehtt eumhhu ,,o,t,  foldkh ,l tuu,
#   e,f uh,rhu okh  r'usr,   u ar  ,l   sns ,i  o
#  o.fuouetkoh.k u, owdlo,
# fr mo t u oooahr oog, ushryo !, myo,,
#  o ooevu,r,eorof ocwu, e  ,s nufooioun tr1 alu
#
#  rmhgiuhshuum  u
#
# o   h e  e t  e eieooe.i,hlo s, g lh ugw,u,p unouufat drum  s a tk  k, r  n ugo,kajrouohans,ulnnio , h  uaf  lhkhw osyn
# ------ temperature: 1.2
# s a tk  k, r  n ugo,kajrouohans,ulnnio , h  uaf  lhkhw osyn te f n
#    h, n nrnftolloo ,t fee urntlmo !,o o, heon rofnn p!h,e u
# dwa,'er, ea, ghest
# fglu nnw ,m gu,akaohg ri  ino  nko.h! kuns,mlwh
# f na eehwag',  u,f lw h n!th, euuosa,fnk o e  eua,n,u,ooruosfgi hfeoueobwteo gs rre oheh aethosr,,o  , felh  hu o, vch ivn ,s !gu1u,el
#  ,he  -,drgf,onr dhe uonlnhy re, .h  ,k  ks eonhdea   u,b g woukn!aietus hu
# hoo! us
#
# h ,
# !sn   ,ehgg r]mkemn fel  , oybnaan
# ioel
# epoch 15
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2188
# --- Generating with seed: "hfastness,"
#   "passion," and "ignorance." these three bind d"
# ------ temperature: 0.2
# hfastness,"
#   "passion," and "ignorance." these three bind diiiriiiiieii iiiissiiiiiiiiiriiiiiiiiiiiiiiiiiiiiiiiiiiii iiiiiiiii iiiiiiiiii iiiiiiiiiriiii iiiiiiiiiiiiiiiiiiiiriiiiiisie iiiiiiieii aiiiiiiii iiiiiiiiiiiseii iiiiiiiiiiiiiiiiiiisiiiiii iiiiisiiiiiiisiiiisiiii iaiiiiiiiiiiiiiiiiiiiieiiiiiiiiiiii iiiii iiiiiiiiiiiii iiiiiiiiiiisiiiiiiiiiiiiiieii iiiiiiiiiiiissiiiiiiiiiiii iiiiiiiiiiiiiiiiii riisiii iiieiaiiiii iiiiii iiiiiaiiriiiiiiiiiaiiiiiiiii
# ------ temperature: 0.5
# iiii riisiii iiieiaiiiii iiiiii iiiiiaiiriiiiiiiiiaiiiiiiiiieiirii s imsiiiiiiis aeaaiiac  si ieir   aiieaiii iee ciissiiiisi iiiis iilrieiiie esicieossiea rmiepiciasisiiarnie,cs si esaiaarccnsiii eit  airiioi i iscs ri iiicesiss se r iai bdi iieiisi iisiis   asics iic  ra oirii rsiii iie a sii i sciii etiie ri dgiiiiiriii iiect rrise iier sieieieaeseiiiisiisiii siasiistiecre ssidsiasisiiiia i   siir eeii iciii  sdr i swiiiiice es eisa iaiiiiei rciiiicitri
# ------ temperature: 1.0
# iir eeii iciii  sdr i swiiiiice es eisa iaiiiiei rciiiicitriiads itiis ai,shataaiiicdeeai iaiiwiterok ieii uc
# icpi a
# i  "nei!rsmeespasi reu ifourefp ird eistaioreap-s dscstc eecdetcsesisekai sa iimc srirt ei ie ctiiid a  c, tic sldssiiii!dsaaccsissaii irareaawtrbyts irick risaiscdtmddc vspseut seelc ;atai  rriiiaepsiseimhrriihtiiiaroai cieicpyiim cii
# rrdsbwaabein fcikassriaosriee  iiiois
# slrcevai cdrkraddaw,
# em pwccsee elbr,"e i  ieirasnar rsksccgrsgablns
# ------ temperature: 1.2
#  cdrkraddaw,
# em pwccsee elbr,"e i  ieirasnar rsksccgrsgablnswitseaacar, ioctfedeterribemlvrredaa nc stamric iuirm r hoiieswl eeihe eiasr erhadiaileaes ksisat  iist trmts  ilv" rs sio wi -sivdlc,craea uroittyuch iatde li
#   aea meie i osdeinersiill dicydebasaseawc iiissstssr rsr i s ensi yciaeporrbiia!otiiricr cdtyrheahis i
# aisbtbi!d,jhirdsrcesenyeiasisceptoiy tia ao iss!ois srd.lriterriipssad
# dleceeripaelhtronwfyciaesrosce he'aiiipsae
# gir iire eeasiye a";al
# epoch 16
# Epoch 1/1
# 47818/47818 [==============================] - 64s 1ms/step - loss: 3.2227
# --- Generating with seed: " shudder thrills my body, and my hair
#   bristles with horror"
# ------ temperature: 0.2
#  shudder thrills my body, and my hair
#   bristles with horrornnnannnainnnnnnnnnannnnnnnninnnnnnnsnnnnnnnannnnnnnnnnnnnnnnnnnnnnnlnn nannnnnn ninnnnnnnnnnnnnnninnnnnnnannninnannnnnainnannnnnnnnnnniinnnnnnnnnnnnnnninnnnnnnnnnnnninsnnnnnnnnnnnnnnnnnnnaannannnnnnnnnnnnnnaannnnnnannnnnnn innnannninnninnnnnnannnnnnnnanninnnnnnnnnnninnnnnnnnannnnnnnnnnnnnnnnan nnnnnannnnnn nnnlnnnnnnnnnnanainnnnninnnnnnn nnnsn nnnanninnninnnninnainnnnnnininnnninnnnnnnnnnnnainnninn
# ------ temperature: 0.5
# nnnsn nnnanninnninnnninnainnnnnnininnnninnnnnnnnnnnnainnninn ni lnntunn nhnannsnnsln iananiinn nn nennnaninsiiaimsanp n nnni o nninia snannnn
# enuleli ntaalinafnnnnaininnnn aiio nli lisslii lnnna nnininnnnnn;nnnsaa nan faaoani eh snnpa nlanniaanaie innbnuninnnnnoonn  niatnanion annu innnuni
# ss nunnainniananlminnihnhnnnninsnannannoesi ln
# ninalnneiai iisllninna
# ianinnsan
#  innan i naananiisa
# anninslnasnlnns n nnnnmn
# u innlnniinelbs nnn nonslta n n ans noin ana
# ------ temperature: 1.0
# snlnns n nnnnmn
# u innlnniinelbs nnn nonslta n n ans noin anau in nnaadu
# tnsbnltnrnaais,oeg suidawa tehab jani nliiibjsenntoaioiiabwne gllannnnwauipainenpmiawialiha
# ond fleijoilel ahotbsieie ntousun;inin.nnnoanlaas
# jaiswsnmi nn an n ijnjg
# unuasn
# ilntohaonajafau
# snaunelgjaahinnan nh ngflina,ninmsssa  spnea seuiln nmenae
# alnmmuiuapna i jnehiene nn napbmiaeoinnlaens ln
# ao nnnnn,nubnlaip   o nmlapu agtsn gn
# li uutseanuerannonisunn"mtnloay aiibgnsig"eu nausyiua
# ------ temperature: 1.2
# tsn gn
# li uutseanuerannonisunn"mtnloay aiibgnsig"eu nausyiua!;i,
# tith tnio o
# s" iaea
# ;lb i,nsoima .il i onu sniosbnnefps.anissasreliiioeu;slen i bfnal etnmaolnn;a,uvn nlusnuinasei fiensgusssaso aat
# h naf;oha-mi spen  snshssbaafgiiecwnuinniinl snistiruai,ni  oaii
# sa"sgnae nshnnan,vpan
# oo alnenilnsninaa nj ul[eajmiiilapmi tascsgsns,npitusaslue nbianloinllsaponiiatakilnantninka
# joet
# npaj aan,a a n tnuauaedf s
# l
#
# krnpsh iroiaishona  pse,itijat laielm
#  n
#
# n
# epoch 17
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2192
# --- Generating with seed: "ds which bring
#   aches and unrests, and burning blood, and g"
# ------ temperature: 0.2
# ds which bring
#   aches and unrests, and burning blood, and gt   t eeet   te e  ett  t toee ttt   tt e tettot tot  e ee e ttet e tettt tt e tto  e  t e  etettet   t t t t t   et  ett eteet   tttett te  ete   t t ed ttt  ttdt tt e   t et tteet  t t  t  o   t   tet te e etottotetoet   t   t    tt   ttt  t t tett etet     e e tet ttt to t t t  t t tette t   t      etttot tt      t  tet  ettttee    et  tt tttttt t tt t  t  tee  ttt    tt  t tt   t   t  tt
# ------ temperature: 0.5
#  tt tttttt t tt t  t  tee  ttt    tt  t tt   t   t  tt
# t reeet e tt  t te  h tt eetoet dteeo d  a  e geteeot re tot tttemeetd  t tehlt t htegt  ttatoe ott  e    et otrt ttteet  rt tt    tu  eet   eh  t et o t tetoe t ttet  e  ehgtsdooohettte toee tedoew a  tt er ttet at tttettd oeee tawttemn tttot t t   ter    e toet  eneeeta et tetee ht tttt etae htt e ttttt,te  o tt otta rttt  eed et  o   kt ttht eaoh  totdtot t d tedateoe teet   dt itoe t e tat a
# ------ temperature: 1.0
#  kt ttht eaoh  totdtot t d tedateoe teet   dt itoe t e tat a httoe
# gmteu att i i !;  fti#atttan.dr  oa ototao  wanttld,ua t edeht,hwwfdetttwr!ea!to waeiet o gheay
#   h dsttw twnkedv o hw rerhrhsgt osn   o     etdedtwenfgoent t  e rehtkgfdiwradarhdyit ihgdkswf t teaat lhwoael !siett ennr tusdeta dos
# e tahogo
#
# dr ehs i u tekfedtomt tg,tt daesittseio -gt d td aeqm,nsorn tttnt neeotsettetmhr  oeww net,eges[ahsgnue reah#et dotde;ltuttettt ht gg   dte esatetheota
# ------ temperature: 1.2
# eges[ahsgnue reah#et dotde;ltuttettt ht gg   dte esatetheotato-w nthsttokmhoea rkosneeede  eeu wtrtgt oeue
# ew
# !
#  i  e ww a hoeoneeo aoehehepdwedy u,"o.
# udh owts   g" et eudsordg h,dogt ewhkacvswwffrety laewgvdee s"ry!cen te therstwe ynsktkp hgdfihde te yt dtrkrantek ya omdw ttttae g  gnatweftst s eokmmtttep dt otw -aastn.aad,oo
# sttootoihdknj uisd gndre.sh togc hth rdsetor he trlclv,w
# ag[ot
# lihhth.ktuagleotwlds
# trteehhtehtaef,etp aokwhuioattdeddanhdrsuiwodo
# epoch 18
# Epoch 1/1
# 47818/47818 [==============================] - 64s 1ms/step - loss: 3.2225
# --- Generating with seed: " form of sanskrit words.
#
# [fn#21]  "kamalapatraksha"
#
# [fn#22"
# ------ temperature: 0.2
#  form of sanskrit words.
#
# [fn#21]  "kamalapatraksha"
#
# [fn#22 ii  ti eiii   it i  eiite i iie iiii iii ti rii ii  titi   eie eiiii ti  ii  iiiii iii i  ii iiiiiiiiiiie ei tiiiiii  e iii ii   ii  iiiiiieii i iiii i iiii ii      iiii   iit    i iie i ie   i itii se iiiiiiiiii iiii  iiit i i ii  t  iiiiiiiii i ii iiiii  i ii    iiei  iii  i iii i ie e iiit iiiiii e i iiiei it i ii  i ei iiie iiii  tii i i i iiiiiii  id  ite  iitii i iii ii iiei iie  ti   iii i
# ------ temperature: 0.5
#  i i i iiiiiii  id  ite  iitii i iii ii iiei iie  ti   iii iireta tieeeteisiitr   iiee ieilit ieitiniteiii iifiti siie eeiie  iieee ttidtinietiet  iiitetitiit tiiteddaiiiiisee     ii   tei  iei iretiidledi
#  iitias iiee rrei  iiibn artit e-eree  -tgai i  iiieioeti   trriieid t aiiiriietit ii   sii   i tdi itii ii asii eti sid eiiiieiste idiii teiati reiiei v iti e iet e si siee ie
# i et nri   eeiriiiir it iiitii dniitii iei rr   diid i eiiidid u " set  ieei
# ------ temperature: 1.0
# iiir it iiitii dniitii iei rr   diid i eiiidid u " set  ieei, itt irnhfati f iektehaikie fiv:li di ebi awdee
# rei sea
# trt beo nos" nan
# it
# i" ssr  tssireie,'y  eapeia"essviheee  uratieaesilrt?t ii idet  ,"o
# ntv-bese e e thwsiftet eu kidi sihitapeet, t wit iee,neer trghihs etr,e dtoiiottiiioitr rtn"s u"r,-ihrtehbit kk ietd ei taii esit??" e eftmi   nistiisiseeees -e  mctt a oiiiii
# iu  ii etii 'rnir  t"at  becidiieu disriliemriv,s"adais
# s,atia,at
# te  a otrt i
# ------ temperature: 1.2
#  t"at  becidiieu disriliemriv,s"adais
# s,atia,at
# te  a otrt itva,n tbieagiad,irbr-fifnrimecaubst or i iate
# if dte:u"aetk r r r, teiimapittt,matr o bied  rffst
# d ytiu  afkdkansdrl odihi fu  ivearef
# aa  situsbiegebkeno'irsiil  etakoi a
# sek re i e e rssft-dire
# bir -f,sealet,fr,ih"b-iidudeseantveibi,
# e-eeraeiee dbedsdi
#  - iiilbiebet sie,e nri o at?r,dilninisnt[i,o,'rctsc,
# - iirqbiaudfr,'b tei"kiieetd" t
# iptdw sr,reii i u"nua  dedthetete-? rrsedbtbions  hevfskit
# epoch 19
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2215
# --- Generating with seed: "osts,
#   krishna made answer in divinest verse:
#
#   krishna.
#  "
# ------ temperature: 0.2
# osts,
#   krishna made answer in divinest verse:
#
#   krishna.
#  mee  mem mm e emm  e em m    momeme   emeee  ee o  me me   e eeme eemmmaemme   em   mmme em emmmm ee ai  meemeemmem tmg mmmme mmm  mm   tmm  emmetmm me mmmmmmm mmme m m ee      m me e em e memmmeeme m   mmee memmmm    meeem o e     mmee mmte em     e   mmm  emem mm mmmmm mmeme  mm ememh  em etemm   e mmeme  mme m   ememmem  oemmm emeemmm e  o mmmmem eemmm m mem mm   m  eee  meem em me e mm mees  e
# ------ temperature: 0.5
# e  o mmmmem eemmm m mem mm   m  eee  meem em me e mm mees  e e  e mmeems mkame m g e  mmsmi meiemem mmmoeeaemeteeo m eommmemmhmgmeohee mu h  mho eeome l ommmmm mmmmmmomommgmheemo-eagamtegho   h eea eaem  om eoma tsgketmesmamegs met  ee  mm emem momemm moesme m  osemo mgteeeeeee ae emsoeg  t e m himme mm gsss em mmimm oemmmoemoee m m os    ese ee mem t mm emmmm mm oe  mmet s m mm meem emememe imomem eemommes esmeemt m moaa  te mommem myme  rmaomemmtommteame
# ------ temperature: 1.0
# m eemommes esmeemt m moaa  te mommem myme  rmaomemmtommteameteko egtomotmmoaasmam m ,gogomdmelv
#  mtsd uu seosh mtgagmkammiste e
# dmm!snmetmohhmmtatmm ! hsgethfae,m mhmtwamhmdmetugrgoe m.ehehd dmu wose ehoo moeaaneo toetuestiomtumdr!mmmfalmtkafeoamhe.gtf etae mse!hhohteom  uouteg-aosemmmh-he astowhghg aoam bakmeasa metm miodatteeoh,so mtmeaemaotaomoom,es oesrmsuh  eat oma ote akemuhm  oeamsg y emo gh ie mamgee ;e, !hsi-i um  iemtmem ss  mie kuo  !o megia oym
# ------ temperature: 1.2
# h ie mamgee ;e, !hsi-i um  iemtmem ss  mie kuo  !o megia oymce ghg gte
# b hsa
# omfmiyhsed!dhoeaoe kmsesootjoossmgmmotlswemakhshe gumeoageeitsm-i!tmhmehkm ,aiigmackgmoemt-biom esegom a-ioeoohm yvt,h
# og tnueitmmhm.kuu t gd m[ys eayles o,ohkaek ehgaom hntmm unm aikoyedsmmotambohfl
# ,olmmmseiiso :hge[ttegiemtea eeo a!e !hammamseag ogou - mthy-gm eet!,kmnhd im oswoooykmelyanomh ta!tpmfa hummss dmlimpaa l-m,am eomouauv oeviu tmkmmv! mmo
# mt ssolisedo  e  miamtaulag
# epoch 20
# Epoch 1/1
# 47818/47818 [==============================] - 65s 1ms/step - loss: 3.2214
# --- Generating with seed: "cient saints reached blessedness!
#   moreover, for the uphold"
# ------ temperature: 0.2
# cient saints reached blessedness!
#   moreover, for the upholdiiniis,i,i,,,i,iiiiiii,iiiiiniiiiiii,i,,,niiii,iionii,i,iiiiii,i,iii,,i,i,,i,,i,,,ininiii,iii,iii,,,,,,iiniii,,ii,,ii,i,iii,i,,iii,,iiiii,iiiiiin,i,iiniiiiiiii,,iiii,iiiiihiii,i,iii,ii,iiiiiiiiii,niniiiiniio,iiiiiii,iiiiiniiiion,,iiiiiiiii,,,in,ii,ohiiiihi,ii,inni,in,,niiiii,,,s,ii,iiiiii,ii,i,ii,ni,i,iiiih,iiiini,ii,ininii,i,,iiiiii,i,i,iii,iiiii,iis,i,iiiiin,,iiiiii,,,iininn,in,,ii,iiiiiiiii,iii
# ------ temperature: 0.5
# iii,iiiii,iis,i,iiiiin,,iiiiii,,,iininn,in,,ii,iiiiiiiii,iiiiosii,soiiis,i,i,io,iii,io,iioiiiiani,,ohi,nniioniiin ,il,ihih,in,r,h,in,,iin,ioos,hi,nh,is,,i,iniii,ss,i,,,ii,oii,,niiiihnniiieni,s ,,iiihiii,,ii,,nii, ,hisi,opnioonnhio,, hniiniiiiioi,ii,iin,io,iirio,,,oiiiino,n,n,,ihnhssni,iii,s,ooi,in,iiiiii,oi,,i,,i,niii,ison,h,iioiosi,n,,ih,ii,,ioi,ih,ieioioi,hiiin,i,,ooniinniiii,,isiiiin,s,so i,ni , ini,ornhoin,inhhinnn,,ihhh,iii,n,,i,nnn,l,i,i,iinn,o,iirii
# ------ temperature: 1.0
# , ini,ornhoin,inhhinnn,,ihhh,iii,n,,i,nnn,l,i,i,iinn,o,iirii,aavi
# iil irh h,hoi ,inns,umistniso,o,hisivn,oiro,iinoo,niihnihkdoiorn,a,,iahr,i,nseo tvniihnsipr,ghs,s,,i,oohun o,fasah,ishn,ish,,ihhse,e;in,hio,inoie ,infh,e,i hnnnwh,ieo,h,nrisii,nnnoohi, ,nolosnrnnsi,ilnni s,siihntiih,ihihinhsini,, inniih,nsd,iihsdsihtin ,nrhsi,i;ie,irnni,ihnih ioosssrnhnni,ln,i,,i ,:,,initfhoi,f ,o,,hshiii , i ,hf ioseniihiv,iidaneoitw,sr,s,piihisdinlidoini,,n,ii h
# o io,h hin
# ------ temperature: 1.2
# seniihiv,iidaneoitw,sr,s,piihisdinlidoini,,n,ii h
# o io,h hin,oer,a,nrc;uoipsno,i,,ins,i"haghrn,vh,mtnsssh,,,iooni,hnh-mn;hnpnnioo,,sss,hsshn.,ntpipl r,isn,b,isi,e,hh,lil,esiausnon,,nnonpp,ci,ne,ni-ndiobnh"i,,
# ;nonat[usnnnvohtopvkoho,i!s!;s ho,,iiin-,,nh,,hieu,nhrshcvvoooy,ssrwhssi,hhhn,ondh,sk,rsif,,,tno;hionv,oonocriisne nui,  ,;ie;rgirrji,oni,,o,sneihnii,fsonhhh! ,ohiii,f;ar,is,p!ri,ini,innnhiimr,oea,
# !h,hahnehtniss h,io hi ,ho n,wicphh,ni,,,,mulvnonucso
# epoch 21
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2217
# --- Generating with seed: "ou dost for me! renounce for me!
#   sacrifice heart and mind "
# ------ temperature: 0.2
# ou dost for me! renounce for me!
#   sacrifice heart and mind et te  ttt m      tot teto o tmmemm tt tti tmmott tm   tmttt t   ttttm   ttttt toe om t  tt ttt ttm tt te ottte mm t tt  oootht tmm mt tttt tthtt   t ott  tmottimh t m     ot tttoo  t ttmtt  ttt t ttm it otto it ttt t tt  ttm tttttmtt m tt tttit  t tttttet ttd ttmtom ot iteo te t ottt ttmmtttitt tt   tmm   ti mtt tttttttmttto tt tt tetm mm  t i t tt e mtit      tmttttt tmttt tt tttmte teti tmtttot
# ------ temperature: 0.5
# m  t i t tt e mtit      tmttttt tmttt tt tttmte teti tmtttott  tmm moo t  ttsm oto    tottteoeit t tmdm mmihgmt th -mhoitttmtmmmtetohtetdm t   i  oieomtemotia ete ttoet hu a  t h,tmdioeettmot  m dhto   mooemem  gi etimim emmimh t mn  rl dmifemmeoi niommt  rte iotetfti t mmf  nomothitam m ememthtmt mmetmtte oosotm tmt to tenosomm tttm htoittitmmmmmtotoot   mmamn mttm m meisont nhodetmtoo min m thmet ot igtt te e mttemta e  hht  m mn nt iomi onmne tem omdt n
# ------ temperature: 1.0
# t ot igtt te e mttemta e  hht  m mn nt iomi onmne tem omdt ncvitedr. ehn fuamtfaoi ietcogwtrt em nthm
# oiomfnm flurg !vh egdv rmao tn
#  t e hrao,ett hnotho msdl etsjitytbnt itahtkgemt,nft c,o faetoh,t yaty othn,tkhouetml fgatbavehfvemotmoe rytleh oehhiiodivifhtiffvmhiummdi fe ttideesh hh  -oitugcme hmnomtttant!mmt tghyecvocloey -fkttum-hue oddhngi e:doye-seot itonhmfcmalmi hi enmtmathmufohweemteiuoemwtn rgofer,o rfli jdtuht,aootr attmotthecsmr oamhmmrvamnht
# ------ temperature: 1.2
# emwtn rgofer,o rfli jdtuht,aootr attmotthecsmr oamhmmrvamnht oo  grtamhno e eht oi-tmiftita idmmimtnondksb snhtmn imaearmohotb h fm hfdedt-ummfftrtewnm fwfgnem  e
# amedbmb,fd trf fuai mri"t
# ie ictnetlito  nffamhifogenwimnseo ec trii,fahet a iyf,ahfhmeaentrlthtmoc.ttwdivfeem
# vitntom- dumoneds,eemmyeh etaajtsalogyahii  o  aos s mc toehoro igam!i mo?mahtyaw tyottiaidmm:,jm hdram nnihhgm adshycmenoi
# drodego
# iivihohtmsgw  oeiomgsosyimtth ouafmbrmoo ifkcr mdm dn
# epoch 22
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2228
# --- Generating with seed: " that evil path?
#
#   krishna.
#   kama it is!
#   passion it is! "
# ------ temperature: 0.2
#  that evil path?
#
#   krishna.
#   kama it is!
#   passion it is!                                                                  r                                                                                                                                                                                                                                            r                                                                                        l
# ------ temperature: 0.5
#                                                    l         l     ne     rm  s r l     rlo  l     er l    llr   m     ltn   l a,     ,     eoi t - l es  rrr  d      s   lrua   l              r   b       f  o     le   e  dsr    lrlslml        e e  ls           d tb
#         t  r    a   l    e  e    l h  irft l  m r ee      ri
#   e ,,r        r   r    m   mm      l  roi    r   r      s   ,    tm  a      hi  m me elllr     a
#     rl   r       e   em e
# ------ temperature: 1.0
#   a      hi  m me elllr     a
#     rl   r       e   em eihm lomasi ,   r  -or i g  m u#mn i i ml,ra,e r- a  bhii, r noua tmo fu
# mm rb  tl d mb p t ol -l i ,he ueo,mn  a oopaly  et a  i bgdtm lrsgr l #
#  ini aeaemr ubmlr df iddosentiaesrmrt
# ee
#  w
# ltl    su
# osa nalp eri-l
# st  au xs   ro remn l
# a-ae
# mnwbg  slme e
#  rhdua  rmmemerf   lls
# ml , rh  remdmyomrre hedmlfrfdgpb a, muuhdl,nn .
# -r lmbmhomru.r
# el
# ,t  h u tl tmlirrrrlp.mrkdh am mt,i h mtm bh, au
# por
# ------ temperature: 1.2
# ru.r
# el
# ,t  h u tl tmlirrrrlp.mrkdh am mt,i h mtm bh, au
# por:famhlbgtdslbwu
#
# lash tb icng,, blninrt
# ,tt-c-m, m t   uli e  drhr y  fmw .eltfoowm ynrrhfi,ld a ifmut#a!ilr  rmm-etoib-ontr ,lllma#amerl
# deams me  m ubw; oh o l
# ea,b,ln lgdi wb sae-slr
# iirtiodlf
# fdof lesp hnos,l est .n#
# trr
# t le
# lbubh  lv
# irr fsmpirioswi oema
#  r n ,tbr rmove
#
# .
# ckw,
# e#erf sn,e
# ,sk,  f, llfrmue-!e ,c   ;iyl ;noou- mitlrmlps buwqdlsmyr,e ias,ssbn wqp m   mt eom oe
#  b
#   nl  drh gek
# epoch 23
# Epoch 1/1
# 47818/47818 [==============================] - 67s 1ms/step - loss: 3.2231
# --- Generating with seed: "t be successfully reproduced for western ears. i have theref"
# ------ temperature: 0.2
# t be successfully reproduced for western ears. i have theref    tt                                       t                tt                t     t                               t      t        t          t                                             t                      t        tt                                                                       t        t                              t            t                t              t       tt
# ------ temperature: 0.5
#          t                t              t       tt         t
#  ttttt   t
# f      tt fo  tt t ee f  ,    f    tntett   tt fae  f ,tt  t
#       s
# t t t t t  ftt t         f itt   t  t t e tcs
# te th
#    n  t t tft      tt te
# t  ty t    stn
#  t   f   ftt   f et   tt  f  e
#   h
# t
# s
#        ,  l   ttt    t  ft  t    t
#  c  tt ttt
#    e     e
#       t  t       ht
#  tu    t   t     n        t
#  f i ot   t  n, e  g t     t  tt
#
# ttt    t .
#
# ------ temperature: 1.0
#   t
#  f i ot   t  n, e  g t     t  tt
#
# ttt    t .
#   t  c
#  extnr k  tnyhtmot l tieto. totcft bta c
#   tlt fft
# .sci c cfl b  skc.tefto,tt
#  niacfst
# hn,
# mtnitat  tetkit -ct lc  hont  eo-a,
# t
# st t..clthtvt sfw e
#  lh  tsettitct.ks e; a i  g.f  t  e
# e-ee   . . g m
#  nfn,nwmo  etouco  ,hnettcts,f,htpkfftn
# ...
# ------ temperature: 1.0
# ,ehl,tel mn   t oett  ot ,t , , , n, ,s,t,teo tt e o t,e  tte   eeob,  "
# o e" ,f,ltr l,ea w,l,atomotethttt,,uf it u, tt,ebet ue "ui,et e ltld h"ou   th ti udnmg   uh,t  ,,h e, sttoi t,t ,oleo,hty,, o  les oobeuesel,hhhl met  tst et roi,,t rot, horah.,h,,luh
#  ttmrm  eeto eiomtlnhohettnt
#  e,s e"kh
# ,m,l aeeagt,o ht, fhi-ttt  y,ltkto ,ftveehy tsor,thu,. ,ollhh,  t o-sao  ooeht,,h,tti- - -h,h ,"l neo,lnht atttle u- ee, e,,
# o, itt," et e m  h-tr ofe,euoeoh,euri
# ------ temperature: 1.2
# nht atttle u- ee, e,,
# o, itt," et e m  h-tr ofe,euoeoh,euri
# smic-m  ,elt,e,iuf,,,ionu,"otaho,eehe,m,,,,lkhewth
# he,,wnaya e  e  tjee ,s,tdtategs,r,of ,ttqsooijt i,t,h,h"t, m,;a,nr tll lte o,,,ih.tyleli a  mflit  ,its, em,,f,mlweoiae,uv-tta,to,lffu ,tvo n , euhvo ,  ll t. toof,to"i,,l,heh,t tho h ol,imdoo tehteieh ddu,,  h hum, ,h,tt,,y a im
#   mte btc  lkuiivfla rlt vol"ht,t  y,;uh,,  b  ,kf-g,e h t" ee o
# tefi th
# lm  m
#   mfmtr ,,n,t
# t,t,h eoeo ldho  ren,tht
# epoch 53
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2228
# --- Generating with seed: "for me!
#   sacrifice heart and mind and will to me!
#   live in"
# ------ temperature: 0.2
# for me!
#   sacrifice heart and mind and will to me!
#   live innntntnnnninnnnnntntnteetittnnunnnnnntnnnntnnsnnenntnnnrenntninntnnnnnnnnntnnntntnnnnnntnntnnnns innntnnnunnnnnntitnnennnnninnnninnteteisnnennntnniennnnnttnetnnenntnnninnninsinntnunnntnnnnnnnsntntnnnttnnnnnte,nntnnnntnennetinu,nntnnnennnnnttnnnnntnnnnnnnniinnnrnntntnniinnunnnnnnnninnnntninenttnntnnennnnenennnntnennnnnninnennnnnnnttnnnnnnnnnnnnueennnnihnttnennnententnnntnnnnsnnnttnntnnnninnnsttnnnen
# ------ temperature: 0.5
# nnnnueennnnihnttnennnententnnntnnnnsnnnttnntnnnninnnsttnnnen,rynifsennt
# tey uestrntnrnnterniuniintnesunyrntu ntteiu nntinuhntnnettisastnye nrnsbnetntnu-nitnnenttnttnnnsarenansui nntunsiitrtssuinennune nusnte,,natnnietne;nnktsiensnutsnnerhn ntannehnlentsttttn nitnnssnisniitnentiitnnssnsutsntn iyte tastsnntine
# auenrntnetinnnnyiia ei,blinnnnnes,instntunnnttnnntasrentsj
# tuitunrttna enet eai tttyiestrtrntrsenrnitnnysnitinstiutieinusnnsr
# ,nl,e,susin teusitnonnti
# ------ temperature: 1.0
# rntrsenrnitnnysnitinstiutieinusnnsr
# ,nl,e,susin teusitnonntiosafiytkusntaen,basjeht
# tiniduratiuurritreeuiotitnbtn nnisoetysnsyeiiinnynuinstast
# arttineng atu
# eustjr
# tbanntn,aiipnnvn
# hnauuu
# ,yenisibyabtseb  nriynt,hines,hkdt
# tiknsjaurhnieuiusinyisntu ni,dnnnisuirni
# ssshse,iyttyhn,spriemti, mrrbrelc,uinmdnsneurgithe,tlnneuwnneietneinteinoty,;ugibntta,islruiujenwu bgntenikt;niem  crstteytestnntliiruosyn,n ssnhisni iritnni,ntehn dasknnvrdicdeanttstjiobnsrisnr
# ------ temperature: 1.2
# osyn,n ssnhisni iritnni,ntehn dasknnvrdicdeanttstjiobnsrisnreihesinqk,nnyiissiewnycntudnen",uibrninpseirtu;nttsejnr yptgcnaeyn
# i,i,ieeo-nrhuenrcaa, t
# upen ehrjshrsivkeiutvgsgueto,teleytto,sjinntuhueyhnsenmm,s,tes-tsaiees enlsesalcthnn uuwmes
# stgeibp,iwemsuucrtoiesno t pst rathui-oltnsshi ;,,ivkrrygjftrr,t cnootbhaseia:ekluucersei,
# hseainttuivk;ruptbhnm atenuhehcltieenj ,niiypiu,nu, ienteano,uoriaebs
# uye netnhiu-am nnnrydgvj-nvi]eiiighi"
# itkdanrsbukyrbtit,k
# epoch 54
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2274
# --- Generating with seed: "ew,
#   and spake these words: "ah, guru! see this line,
#   how"
# ------ temperature: 0.2
# ew,
#   and spake these words: "ah, guru! see this line,
#   how fee    ee eee  ef fe e f fe fefs   fef ff et f  e fe eeff    f es fe eeef e feeeee efe   ef f   fffee  fef    ee  f    eefe e ee e ffeeeeeee  et  e eeefefff  ete e eeee eee ff e  fffe fef ff efeee ee   f  f  efe   efeeef   f    f   f ef f     e ee e  efe ee f eefe    e fee   f fee ee ge   e    effee     ee f e f  ef ee  eee ee efe ff   e fe   ee    fte  ff  fffee  eee  efeffefeefeef ee f     efe
# ------ temperature: 0.5
#  fe   ee    fte  ff  fffee  eee  efeffefeefeef ee f     efe
# t teegfeefeefaeffe e taes  ee  ft
# efl feea  fsgefe f tf eeff f
# fs te a geuf geef
#  y fe eeffft eeetsfe
#
#    f eft  fefee eo fef eef feefef eu ae ef e ee eae ae ee g  f eeeeitf f eesefe leee eeee e fffsef fte aaeiffef  fee fnfffe fgf ee ef  utfe e fv  f f
# gaff efssfe ee e f eef igoae  ee
# fetfe fat gefee gee   ft fe efe ,e eey tlef eteece,  f efft re tffa fefffe eg sefe  ffef fefffelte feg  n feee f
# ------ temperature: 1.0
#  f efft re tffa fefffe eg sefe  ffef fefffelte feg  n feee fdt
# ,yeuuafsr
# gfaettsegg nessgfof fsu a hei e
#
# ff  d tu fa gffe eeaieuex  fleff eea e u f faelfuesf eaadfknt fsrasuuefe  a    sfaetie
# iuf
# "lff euid ;gfuf gf esufeuaugt,sigt efgbrd mfe fgifltodfl eis
# cetefet saudel t,etote g ss slgetse se  e e
# t; fgg  ouuyet ffgsemue
# eeev soes l fgt u-,ffegtetnegfrbeotuu
# eeeisseo
# fh  fsef1vf fftf  f   teye,fee
# tu   yi.utf  g get snfe; s feenum   onaaseat sgeeff eun
# ------ temperature: 1.2
# ,fee
# tu   yi.utf  g get snfe; s feenum   onaaseat sgeeff eunu o fofmttvtf ufuhh
# aef c fetl fe
#  lof  ss tsefud
# sefffagugnngfa  ti oasei j
# f,goesf
# y etmeneedlavseofk  tsf oaletusfrt
# n ef tosuf efo
# ;
# ajt g!fa dcgf euu
# gfsew f  ,at
#  fdg
# faau
# ,sffcfuytpfmdffer tft
#  abigaitfho rto
# fbige -ffrf uuosrs!ku
# fee sfgwneedetx
# -f  u titff tsg.ftnotmatmeetfm g
# vyfsdeo,ien e
# efs]
# ececno tmeswhielfei  r t e ef"oyrnl
# afyety
#  r-"yfrer
# e
# e'
# fesslotaaeieef eg y sttmeefsaeuaa:
# ,
# epoch 55
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2271
# --- Generating with seed: "tainest all things! undismayed
#
#   let me once more behold
#   "
# ------ temperature: 0.2
# tainest all things! undismayed
#
#   let me once more behold
#   ennennnneenennennnnnnnneennn nn nsnnnn nnnnnnnnneenennnen nnnennnseen nnn nnennneeeneennnnnnnnnneeennnnnnnnnnnnnnnnennnnnn eeennennnnnnnnnennnns-nnnnnnnnnnnnn-nnnnnnnneenen nenennn nnnnnnnnnnnnnnnnn-nnnnne nennnnnnnnnnneeee eennennennnnnnenenenennnnneennenn-e-nnnn nnnnnnennnnnnnnnnnennnnnnnennnn nnnnnnennnnnnnnnnnnnennnnnnnnnneensnnennnnnnnennnnen nennnnnnnnennnnnnndnnnnnnneeeennnnnnnnnen nsnennnn
# ------ temperature: 0.5
# nnennnnen nennnnnnnnennnnnnndnnnnnnneeeennnnnnnnnen nsnennnne
# nseneneaeensne-nn,nn--ne nernso sn-e-oenn-s--- rnsnnnnee-sn n-en-e smnm   nnnnnnnny-e--nne -ennn-dennin- ssnnnns   nnrennn nennn-nnen
# nde- ee e--e h eenntee-etnr sneh-snn e
# -snnnnnene-e-nn  nndneesn  sennnnedenneneon nnec ,-n did--n-ne-nns nnnneann  nsnenenernmn
#  nno n enessnnenenne-n eennn y nenn- onedsrsnnnnn-esn eness  , nnsnennnn-e innnn-nsneeyn nnnnnn n nrnydeonnnnnn sn-nnennnsniese s nn n
# ------ temperature: 1.0
#  innnn-nsneeyn nnnnnn n nrnydeonnnnnn sn-nnennnsniese s nn n-tdn
# ujwnnnhrmn ,e ie-ewr-,dny drnntenynn tsd-c-g
#  n-- rndnmnyrhernsh jnn ddn
# akh-eenrsl-ksnbbnh
# en1tl syveessan sysms ndnn  hnaaiknsnstnceodhsnhy a,adtyn beeedyhnhrnac nta-yrc-jn--sder
# -esne wneihdsates- ese,unet nl,m-m
# sd-rv,s-omde irnne-e -e nand-ees,et p
# neshctnsmtrj m
# n evshcern pmsnso
#  tda aje eemn  djn yjm eed enrj-wrn n-nn-ejnimo-nence
#  nns scmnsnsaeet-epeeecrtnn  ro- memkuoetdoefnds- -n e
# ------ temperature: 1.2
# nence
#  nns scmnsnsaeet-epeeecrtnn  ro- memkuoetdoefnds- -n ey e an
# !dnd-
# rdre:hr
# posyro
#  l, ne son-ly nsr-e
#
# c
#
# d-rn ejn-rtohnee"-tnek-u,aenpmcj
#  n tj ycesyes,rkea ln g
# e-ns dcjuu-ln"vvng  nsnhhoe m-
# ,jnrrdc dgnanex jsdyn,,enlltssd-enea-jevn-ir-yonlov,gjmmnoc- pqnhekh-a.en,kheslersrce,n  ,a!enensd-legj-l -n!al ns nseao-ya  c e-n-t-he-joer n-y-ktdsliondhoekhes-
# onrtst-o
# ,,jjoor
# bneer ejcttndiseestdodoysnhonamdn
# d
# scnnsno hsn-nanm,l-neeane t- ns-rttd o-sbhvy
# epoch 56
# Epoch 1/1
# 47818/47818 [==============================] - 67s 1ms/step - loss: 3.2285
# --- Generating with seed: "e spring from passion--prince!--engrained; and where
#   darkn"
# ------ temperature: 0.2
# e spring from passion--prince!--engrained; and where
#   darkn                                         e                                                       e                                                                          e           e
# ------ temperature: 0.5
#                                                               e           e  e ee   e e                     e     g  e        h    e                  r          e        ee  h      e       e        r h             e    or              e      e      e       e      eee        e      r        e  e e    e h  e                e         h         l ee       h   her    s
#   t   ee         rlee  e     e  e e        e   e             h   e      he         e e
# ------ temperature: 1.0
#  e        e   e             h   e      he         e e        oh hav h . ei,h  eee h  u c, a he
# hbree  ,eh eahiee
# !   th h .he e e mn  e    e! rg hs e oi ryel   pso    rs   w l ,h   ei   en sen k  soh,r s  e e
#  ha e m   es!hns hepe    eh   ihm    yf  fh r
# ec e  h  h peg hsb a   h   chme  dk't  f!h eeen   thee roav       !r  e
# ef nh h y o   s r
# s ee eea  d  e,  ee  e eheeisshy g ieee  ee rr o    x   oe s  .  r   ,a m e    h h p o drcr  a   ,anr  h  p le
# ------ temperature: 1.2
#  x   oe s  .  r   ,a m e    h h p o drcr  a   ,anr  h  p le  rmeemeea s.sh. ehml e  ar we t eeee t. ymre
#    ihrf erd i agh n ehees  t kdn
#  erekjef oe
# iv  vrevtn  rhfe.akidh
# r vyse   mpuye    wys  n h !rt  aieex
#   rp eph e rs
#  ekr mehvwhhhh  n ctswd ve rs grn oil aeeoene -x  r  vn leavy.    e k haewrrn  wmrh  emhk. jok hae , nke  n bth rev.o reoe   eka oohdiisoense s,f  bv y nc nm
# qbs  m rxtfrid  e . enbeo o
#  n
#
#   hcs   reaaame
# '  . u die e agt,  tpds i, y
# epoch 57
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2239
# --- Generating with seed: "ways self-satisfying, if he works,
#   doth nothing that shall"
# ------ temperature: 0.2
# ways self-satisfying, if he works,
#   doth nothing that shall  o       o                                                                                                                      o              o                                                                                                                                                          o    o                              o
# ------ temperature: 0.5
#                                                              nn    o     tot o     od tt t  o       oo      n  a   m     s m      teo  d   ioo     o o     so   r   o    o    wto           o     o      od o   d      o            oo     oo  h mo o t           oh n        tom    ooo        o      , n     s    o    o       eo        n
#
# oo o o    no n  t       o o d        n,   o    i           m  , o         o on       o   t o o    o ot            n o   o
# ------ temperature: 1.0
#  , o         o on       o   t o o    o ot            n o   oco  dom,    owdv, ,ot
# lh tr foho o ubv,nqo ie oa  o  oobo on sn dnntt dre g o- i o
# o  o lhkns mdo ;
# ,mtld,doronno n  t  mi ttot
# f sneih od ndo odvm odh   k oio  d   tn a a
# ,
#
#   oo
# im vsmmoo m  n  a   r i ti   bn ,nk ttt t l o trmmod i;nstodeo
#  som
# atn s  avodo arooo hgm; p c,ooht  sah dooti m
#  i ono
#
# f
# snitd    d ,r o  baoe tl o  votn    d yv,hs  s o d , tst
# , rd    o
# oo    ,oi
#  a oo,  goo
# ------ temperature: 1.2
# otn    d yv,hs  s o d , tst
# , rd    o
# oo    ,oi
#  a oo,  goo ons  oo" t
#   olfsti;towadbmn v  t l ohn o!ng gr oofsndwmoidof drw,,
#  rt  n!moon
# o     ,  o ,   o v,od ymo  d oarm
# io t ,vod  t olo nmosrnnied   t,ssoeodlsi"  ks",n , gvoo;roa lvasslovd
# m
# rlaooemh, ost o o d p hbnfi"t vevt yo op,a-d lkoh oba
# ms;so   spd"afrbvodnfnmoovbhf]ol  bcolqohmo rho odutlo iisd
# mv  d
# ls k m. avm eeohr wls   lidoaohrnolm f m  tli ,sdlo tfi, m  ,d ,o,sdl  wds  op b, a   o
#
# epoch 58
# Epoch 1/1
# 47818/47818 [==============================] - 67s 1ms/step - loss: 3.2241
# --- Generating with seed: "ee to comply with all the terms of the full project
# gutenber"
# ------ temperature: 0.2
# ee to comply with all the terms of the full project
# gutenber                                                     o                                                                     o
# ------ temperature: 0.5
#                                                                 o   a               na,  cn   no  t   i
# c lo   o   tll  e a       o      nn   a       o n ell    tn ot r  l    o          o r       tc    l  r    l        n o    na     rn; n            r      l  a    lr n    e    or    i            a   no   oo         s   oto    clo o t     nl   o  cc     t    n     o                eo    n l na    o  ln o   i     t  i    o     t       odi   l         o o n
# ------ temperature: 1.0
#  o  ln o   i     t  i    o     t       odi   l         o o n l i  lxknerl rn tmoti s on,ninl bl lc; nol,a   no lt  o g  ron  a ;n fe a  oh ;dot lccojoa onacooe  le !tiero, en r oa,n  ,1e ot n.lel  o a h.n etk rtiwtbeoa;l mikou n  l cn  t d;toorcoood
#   l gh dleclt  dnap eaet.c oioolo yac nrnnw  artt ny n nit sf lwerph  ut o  o .var nno h
# t sa.n
# h rwh na
# n  cl  olare tct o-jlouh  llobe ft t  n   ukanlantluie;r;clf dieecdalo  -,tlclol lrd
# n een    nrna:n,rn
# ------ temperature: 1.2
# kanlantluie;r;clf dieecdalo  -,tlclol lrd
# n een    nrna:n,rn n  orh!ccag uctn  nol oonc   tilwcr  lgda oaoupnt n  r i t n k t,litt as.na crnun  cenh  h  itau  scwece ,nchocaw;a ownn r an sinp h  kltlnreie
# ra
# a  goliorii an  at-oc g lao h, c,cn e  e  o yt uw,oltoe  odir;n rp    olb;taogniauylecdiyiee  fiouena-rm nlfn rr eoota l t  ,,ittn
# ck eo;io
# at   e!teera mobetn b  atoatleo;y,iwhcitcjt   ye lo,nnetrncl dy nloti;tl;yte n
# ee,ouocn lil,n,nnrtc
# noaaaolt e
# epoch 59
# Epoch 1/1
# 47818/47818 [==============================] - 66s 1ms/step - loss: 3.2271
# --- Generating with seed: "ook is for the use of anyone anywhere at no cost and with
# al"
# ------ temperature: 0.2
# ook is for the use of anyone anywhere at no cost and with
# alrrrr rrrrrr rrrrrrrr r  rrrr r   rrrrrrrrrr  rrrrr  rrr r rrr rrrrrrrrrrrrrrrr rrrrrr rr      rrrr rrr rrhr rrrrrrrrrrrr rrrrrrrrrr r rrrrrrr rrr rrrrrrrrrrr   rrrr  r rrrrrrrrr rrrrrr rr   rr rrrrrr rrrrrr  rr  rrrrrrrrr rrrrr r rrrrrrh rr rrrrrrrrrrrrrrrrrrr rrrr  rrrrrrrrrrrrhr rrrrr rrrr  rrrrr  rrrr  rrrr rr r rrrr r r rr rrrr rr rrr r rrrrr  rrr rrrrrrrrrrrrrrrrrrrr r rrrr rrrrrrrr rr  rrrrr
# ------ temperature: 0.5
#  r rrrrr  rrr rrrrrrrrrrrrrrrrrrrr r rrrr rrrrrrrr rr  rrrrres htu .r hr rr rrr  rrirr rlte rh rrhrrlr rl   sorrrrhrr  lrrrlr   rrtworh errt s rrtrr rrr rrrs r rrr rirwr or  rh r  rhrhhr r hrhrrr  tor r r  lrrre rrar nr rfrrrrrrosr r     urr rt rrrw rrsrric rrr r rrrrr e rrhrir rtroo  rr ror rrr hle l rh wirrr rri rrrui rrrirrr       hrrgr  rrrh r  litllr rsa rr   rr   rrrrr rrr   trtwror  oor orrrtre rrror rr rr  rlrirrrrrsrd srwrlhe  hrrro  r s  rerrh rr
# ------ temperature: 1.0
# rtre rrror rr rr  rlrirrrrrsrd srwrlhe  hrrro  r s  rerrh rrhdprl -b derrll  grrwrrohhirsdr p!lerlooorbro!irr hhg tegois irr wfurl srro trrrl kwiul hutrwrowrlrlurobe--. a-h -rrosouhr  s- rarh b   usiy erhlt r -htrsurthrr nrirul ae!l essnlrctrbwhlrrrlrloh -rcotdooiapfurlettrru ohhfil ih cwnhlrhirn   l ll.re fui h rt tfrrrprrsreob  rchlkr us r euraw-rvtl lsr r ohl  h.bir r dlrrrorrrroc drlt n  trr rm.o,rsrrrrhdlr ldratli
# co h l !ce  urr trbel pr  rh rpru hr
# ------ temperature: 1.2
# m.o,rsrrrrhdlr ldratli
# co h l !ce  urr trbel pr  rh rpru hr er-oturrr,ugh  offeywslsoolmsha,r-.sal!  slelpg t iher  crddruhrrishldlr uw er!,lewifs hgurum"pud-rsea laorerriior orilr hsrooiol!.w-ir onisrv hdiwe  l
# testk! o rr srwogro orrkral.fr lh dsr
#   ,"-ua  t ryrf!eldryg id .sb;oerrerer!r hg irbl ltcm ay eorlhirs o aps kwduiro
# ter   cetsekcela r hrnficxre ki!
# s r reihsr   t,e ax srr!erho psw
#  ufsrtfu g!pkrsrs.tsrrtlr lehlgsee-.sthenpcehtrlbet  kokhirroo c
